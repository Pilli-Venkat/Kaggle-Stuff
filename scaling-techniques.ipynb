# %% [markdown]
# <a href="https://www.kaggle.com/code/venkatasaii/scaling-techniques?scriptVersionId=123255472" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np
import pandas as pd

# %%
X = np.array([1,2,3,1,2,1,2])
X= X.reshape(-1,1)

# %% [markdown]
# ## 1) Standardization :
# mean = 0 , std = 1

# %% [markdown]
# ### Implementation

# %%
def Standard_Scaler(x):
    return (x - np.mean(x))/np.std(x)
print(Standard_Scaler(X))
# Out:
# [[-1.02062073]
#  [ 0.40824829]
#  [ 1.83711731]
#  [-1.02062073]
#  [ 0.40824829]
#  [-1.02062073]
#  [ 0.40824829]]

# %% [markdown]
# ### Scikit-learn

# %%
from sklearn.preprocessing import StandardScaler

scaler_obj = StandardScaler()

print(scaler_obj.fit(X))
print(scaler_obj.transform(X))
# Out:
# StandardScaler()
# [[-1.02062073]
#  [ 0.40824829]
#  [ 1.83711731]
#  [-1.02062073]
#  [ 0.40824829]
#  [-1.02062073]
#  [ 0.40824829]]

# %% [markdown]
# ## 2) Normalization :
# Scales value 0 to 1

# %% [markdown]
# ### Implemenation

# %%
def Normalize(x):
    return ( x- min(x))/(max(x) - min(x))

print(Normalize(X))
# Out:
# [[0. ]
#  [0.5]
#  [1. ]
#  [0. ]
#  [0.5]
#  [0. ]
#  [0.5]]

# %% [markdown]
# ### Scikit-Learn

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
from sklearn.preprocessing import MinMaxScaler
norm_object = MinMaxScaler()
norm_object.fit(X)
print(norm_object.transform(X))
# Out:
# [[0. ]
#  [0.5]
#  [1. ]
#  [0. ]
#  [0.5]
#  [0. ]
#  [0.5]]
